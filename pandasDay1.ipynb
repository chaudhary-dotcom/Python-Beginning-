# %% [markdown]
# <a href="https://colab.research.google.com/github/chaudhary-dotcom/Python-Beginning-/blob/main/pandasDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Automobile_data (1).csv')
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df = pd.read_csv('/Automobile_data (1).csv', na_values = {
    'price': ['?', 'n.a'],
    'stroke': ['?', 'n.a'],
    'horsepower': ['?', 'n.a'],
    'peak-rpm':['?', 'n.a'],
    'average-mileage': ['?', 'n.a']

})

print(df)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.to_csv('/Automobile_data (1).csv')

# %%
#find the most expensive car company name
df[['company', 'price']][df.price==df['price'].max()]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
#print all toyota cars details
car_manufactures = df.groupby('company')
toyotaDf = car_manufactures.get_group('toyota')
toyotaDf
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
#count total cars per company
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
#find each company highest price car
car_manufactures = df.groupby('company')
priceDf = car_manufactures[['company','price']].max()
priceDf
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
car_manufactures =df.groupby('company')
priceDf = car_manufactures['price'].max()
priceDf
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
#find the average milage of each car making company
car_manufactures = df.groupby('company')
milageDf = car_manufactures['average-mileage'].mean()
milageDf
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
#sort all cars by price column
carsDf = df.sort_values(by=['price', 'horsepower'], ascending = False)
carsDf.head(5)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0

# %%
#concatenate two data frames using the following conditions
#create two data frames using following dictionaries
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMW', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
carDf1 = pd.DataFrame.from_dict(GermanCars)

japneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58900]}
carDf2 = pd.DataFrame.from_dict(japneseCars)

carsDf = pd.concat([carDf1], keys = ['Germany', 'Japnese'])
carsDf
# Out:
# <ipython-input-45-020a65992734>:9: FutureWarning: The behavior of pd.concat with len(keys) != len(objs) is deprecated. In a future version this will raise instead of truncating to the smaller of the two sequences
#   carsDf = pd.concat([carDf1], keys = ['Germany', 'Japnese'])
#             Company   Price
# Germany 0      Ford   23845
#         1  Mercedes  171995
#         2       BMW  135925
#         3      Audi   71400

# %%
#concatenate two data frames using the following conditions
#create two data frames using following dictionaries
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMW', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
carDf1 = pd.DataFrame.from_dict(GermanCars)

japneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58900]}
carDf2 = pd.DataFrame.from_dict(japneseCars)

carsDf = pd.concat([carDf1, carDf2], keys = ['Germany', 'Japnese'])
carsDf
# Out:
#               Company   Price
# Germany 0        Ford   23845
#         1    Mercedes  171995
#         2         BMW  135925
#         3        Audi   71400
# Japnese 0      Toyota   29995
#         1       Honda   23600
#         2      Nissan   61500
#         3  Mitsubishi   58900

# %%
#Merge two data frames and append new data frame as a new column
car_price = {'Company': ['Toyota', 'Honda', 'BMW', 'Audi'], 'Price': [23845, 17995, 135925, 71400]}
carPriceDf = pd.DataFrame.from_dict(car_price)

car_horsepower = {'Company': ['Toyota', 'Honda', 'BMW', 'Audi'], 'horsepower': [141, 80, 182, 160]}
carHorsepowerDf = pd.DataFrame.from_dict(car_horsepower)

carsDf = pd.merge(carPriceDf, carHorsepowerDf, on = 'Company')
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMW  135925         182
# 3    Audi   71400         160

# %%
df.head(3)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0

# %%
#checking missing values
print(df.isnull().sum())
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# True

# %%
#finding rows with missing values
print(df[df.isnull().any(axis=1)])
# Out:
#     index  company body-style  wheel-base  length engine-type  \
# 22     31    isuzu      sedan        94.5   155.9         ohc
# 23     32    isuzu      sedan        94.5   155.9         ohc
# 47     63  porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage  price
# 22             four          70               38    NaN
# 23             four          70               38    NaN
# 47            eight         288               17    NaN

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
#df.fillna(34, inplace=True)
#print(df.isnull().sum())

# %%
priceDf = df.sort_values(by=['price'], ascending = True)
priceDf.head(5)
# Out:
#     index    company body-style  wheel-base  length engine-type  \
# 23     32      isuzu      sedan        94.5   155.9         ohc
# 22     31      isuzu      sedan        94.5   155.9         ohc
# 47     63    porsche  hatchback        98.4   175.7       dohcv
# 13     16  chevrolet  hatchback        88.4   141.1           l
# 27     36      mazda  hatchback        93.1   159.1         ohc
#
#    num-of-cylinders  horsepower  average-mileage   price
# 23             four          70               38    34.0
# 22             four          70               38    34.0
# 47            eight         288               17    34.0
# 13            three          48               47  5151.0
# 27             four          68               30  5195.0

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             61 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
#rename columns with a prefix or suffix
df = df.add_prefix('_')
df = df.add_suffix('_d')
df
# Out:
#     ___New_New_New_index_Data_Data_d_d ___New_New_New_company_Data_Data_d_d  \
# 0                                    0                          alfa-romero
# 1                                    1                          alfa-romero
# 2                                    2                          alfa-romero
# 3                                    3                                 audi
# 4                                    4                                 audi
# ..                                 ...                                  ...
# 56                                  81                           volkswagen
# 57                                  82                           volkswagen
# 58                                  86                           volkswagen
# 59                                  87                                volvo
# 60                                  88                                volvo
#
#    ___New_New_New_body-style_Data_Data_d_d  \
# ...

# %%
df.iloc[3:7,:]
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3         102               24  13950.0
# 4         115               18  17450.0
# 5         110               19  15250.0
# 6         110               19  18920.0

# %%
df.rename(columns=({'wheel-base':'wheel'}), inplace=True)

# %%
df.head()
# Out:
#    index      company   body-style  wheel  length engine-type  \
# 0      0  alfa-romero  convertible   88.6   168.8        dohc
# 1      1  alfa-romero  convertible   88.6   168.8        dohc
# 2      2  alfa-romero    hatchback   94.5   171.2        ohcv
# 3      3         audi        sedan   99.8   176.6         ohc
# 4      4         audi        sedan   99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.rename(columns = ({'body-style': 'body'}),inplace = True)
df
# Out:
#     index      company         body  wheel  length engine-type  \
# 0       0  alfa-romero  convertible   88.6   168.8        dohc
# 1       1  alfa-romero  convertible   88.6   168.8        dohc
# 2       2  alfa-romero    hatchback   94.5   171.2        ohcv
# 3       3         audi        sedan   99.8   176.6         ohc
# 4       4         audi        sedan   99.4   176.6         ohc
# ..    ...          ...          ...    ...     ...         ...
# 56     81   volkswagen        sedan   97.3   171.7         ohc
# 57     82   volkswagen        sedan   97.3   171.7         ohc
# 58     86   volkswagen        sedan   97.3   171.7         ohc
# 59     87        volvo        sedan  104.3   188.8         ohc
# 60     88        volvo        wagon  104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# 1              four         111               21  16500.0
# ...

# %%
filtered_df = df[df['horsepower']>100]
filtered_df
# Out:
#     index        company         body  wheel  length engine-type  \
# 0       0    alfa-romero  convertible   88.6   168.8        dohc
# 1       1    alfa-romero  convertible   88.6   168.8        dohc
# 2       2    alfa-romero    hatchback   94.5   171.2        ohcv
# 3       3           audi        sedan   99.8   176.6         ohc
# 4       4           audi        sedan   99.4   176.6         ohc
# 5       5           audi        sedan   99.8   177.3         ohc
# 6       6           audi        wagon  105.8   192.7         ohc
# 7       9            bmw        sedan  101.2   176.8         ohc
# 8      10            bmw        sedan  101.2   176.8         ohc
# 9      11            bmw        sedan  101.2   176.8         ohc
# 10     13            bmw        sedan  103.5   189.0         ohc
# 11     14            bmw        sedan  103.5   193.8         ohc
# 12     15            bmw        sedan  110.0   197.0         ohc
# ...

# %%
filtered_df = df[(df['horsepower']>100) & (df['company'].str.startswith('p'))]
filtered_df
# Out:
#     index  company         body  wheel  length engine-type num-of-cylinders  \
# 45     61  porsche      hardtop   89.5   168.9        ohcf              six
# 46     62  porsche  convertible   89.5   168.9        ohcf              six
# 47     63  porsche    hatchback   98.4   175.7       dohcv            eight
#
#     horsepower  average-mileage    price
# 45         207               17  34028.0
# 46         207               17  37028.0
# 47         288               17      NaN

# %%
filtered_df = df[(df['horsepower']>50) | (df['company'] == 'audi')]
filtered_df
# Out:
#     index        company         body  wheel  length engine-type  \
# 0       0    alfa-romero  convertible   88.6   168.8        dohc
# 1       1    alfa-romero  convertible   88.6   168.8        dohc
# 2       2    alfa-romero    hatchback   94.5   171.2        ohcv
# 3       3           audi        sedan   99.8   176.6         ohc
# 4       4           audi        sedan   99.4   176.6         ohc
# 5       5           audi        sedan   99.8   177.3         ohc
# 6       6           audi        wagon  105.8   192.7         ohc
# 7       9            bmw        sedan  101.2   176.8         ohc
# 8      10            bmw        sedan  101.2   176.8         ohc
# 9      11            bmw        sedan  101.2   176.8         ohc
# 10     13            bmw        sedan  103.5   189.0         ohc
# 11     14            bmw        sedan  103.5   193.8         ohc
# 12     15            bmw        sedan  110.0   197.0         ohc
# ...

# %%
filtered_df = df.query('horsepower > 100')
filtered_df
# Out:
#     index        company         body  wheel  length engine-type  \
# 0       0    alfa-romero  convertible   88.6   168.8        dohc
# 1       1    alfa-romero  convertible   88.6   168.8        dohc
# 2       2    alfa-romero    hatchback   94.5   171.2        ohcv
# 3       3           audi        sedan   99.8   176.6         ohc
# 4       4           audi        sedan   99.4   176.6         ohc
# 5       5           audi        sedan   99.8   177.3         ohc
# 6       6           audi        wagon  105.8   192.7         ohc
# 7       9            bmw        sedan  101.2   176.8         ohc
# 8      10            bmw        sedan  101.2   176.8         ohc
# 9      11            bmw        sedan  101.2   176.8         ohc
# 10     13            bmw        sedan  103.5   189.0         ohc
# 11     14            bmw        sedan  103.5   193.8         ohc
# 12     15            bmw        sedan  110.0   197.0         ohc
# ...

# %%
sorted_df = df.sort_values(by=['horsepower', 'price'], ascending = [True, False])
print(sorted_df)
# Out:
#     index        company         body  wheel  length engine-type  \
# 13     16      chevrolet    hatchback   88.4   141.1           l
# 57     82     volkswagen        sedan   97.3   171.7         ohc
# 55     80     volkswagen        sedan   97.3   171.7         ohc
# 40     53         nissan        sedan   94.5   165.3         ohc
# 53     71         toyota        wagon   95.7   169.7         ohc
# ..    ...            ...          ...    ...     ...         ...
# 34     46  mercedes-benz        sedan  120.9   208.1        ohcv
# 46     62        porsche  convertible   89.5   168.9        ohcf
# 45     61        porsche      hardtop   89.5   168.9        ohcf
# 26     35         jaguar        sedan  102.0   191.7        ohcv
# 47     63        porsche    hatchback   98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# 57             four          52               37   7995.0
# ...

# %%
mean_price = df.groupby('company')['price'].mean()
print(mean_price)
# Out:
# company
# alfa-romero      15498.333333
# audi             16392.500000
# bmw              27213.333333
# chevrolet         6007.000000
# dodge             6303.000000
# honda            10195.000000
# isuzu             6785.000000
# jaguar           34600.000000
# mazda             9654.800000
# mercedes-benz    35040.000000
# mitsubishi        6689.000000
# nissan            8289.000000
# porsche          35528.000000
# toyota            8216.857143
# volkswagen        8435.000000
# volvo            13177.500000
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
#using basic pivot
pivot_df = df.pivot(index = 'index', columns='company', values='price')
print(pivot_df)
# Out:
# company  alfa-romero     audi  bmw  chevrolet  dodge  honda  isuzu  jaguar  \
# index
# 0            13495.0      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 1            16500.0      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 2            16500.0      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 3                NaN  13950.0  NaN        NaN    NaN    NaN    NaN     NaN
# 4                NaN  17450.0  NaN        NaN    NaN    NaN    NaN     NaN
# ...              ...      ...  ...        ...    ...    ...    ...     ...
# 81               NaN      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 82               NaN      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 86               NaN      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 87               NaN      NaN  NaN        NaN    NaN    NaN    NaN     NaN
# 88               NaN      NaN  NaN        NaN    NaN    NaN    NaN     NaN
#
# ...

# %%
df_selected =df[['company', 'price']]
df_selected.head()
# Out:
#        company    price
# 0  alfa-romero  13495.0
# 1  alfa-romero  16500.0
# 2  alfa-romero  16500.0
# 3         audi  13950.0
# 4         audi  17450.0

# %%
df_selected = df.loc[:,['company', 'price']]
df_selected
# Out:
#         company    price
# 0   alfa-romero  13495.0
# 1   alfa-romero  16500.0
# 2   alfa-romero  16500.0
# 3          audi  13950.0
# 4          audi  17450.0
# ..          ...      ...
# 56   volkswagen   7975.0
# 57   volkswagen   7995.0
# 58   volkswagen   9995.0
# 59        volvo  12940.0
# 60        volvo  13415.0
#
# [61 rows x 2 columns]

# %%
df.filter(items=['company', 'price', 'horsepower']).head()
# Out:
#        company    price  horsepower
# 0  alfa-romero  13495.0         111
# 1  alfa-romero  16500.0         111
# 2  alfa-romero  16500.0         154
# 3         audi  13950.0         102
# 4         audi  17450.0         115

# %%
df[['company','price']][ df.price == df['price'].max()]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
df[['company', 'price']][df.price==df['price'].min()]
# Out:
#       company   price
# 13  chevrolet  5151.0

# %%
df.head(14)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...

# %%
most_expensive = df.loc[df.groupby('company')['price'].idxmax()]
most_expensive
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 19     28          honda        sedan        96.5   175.4         ohc
# 21     30          isuzu        sedan        94.3   170.7         ohc
# 26     35         jaguar        sedan       102.0   191.7        ohcv
# 31     43          mazda        sedan       104.9   175.0         ohc
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 39     52     mitsubishi        sedan        96.3   172.4         ohc
# 44     57         nissan        sedan       100.4   184.6        ohcv
# ...

# %%
chepest = df.loc[df.groupby('company')['price'].idxmin()]
chepest
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 3       3           audi        sedan        99.8   176.6         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 17     20          dodge    hatchback        93.7   157.3         ohc
# 18     27          honda        wagon        96.5   157.1         ohc
# 21     30          isuzu        sedan        94.3   170.7         ohc
# 24     33         jaguar        sedan       113.0   199.6        dohc
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 32     44  mercedes-benz        sedan       110.0   190.9         ohc
# 36     49     mitsubishi    hatchback        93.7   157.3         ohc
# 41     54         nissan        sedan        94.5   165.3         ohc
# ...

# %%
def add_five(a):
  return a + 5

df['price'] = df['price'].apply(add_five)
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13505.0
# 1             four         111               21  16510.0
# 2              six         154               19  16510.0
# 3             four         102               24  13960.0
# 4             five         115               18  17460.0

# %%
df[['company', 'price']].head()
# Out:
#        company    price
# 0  alfa-romero  13505.0
# 1  alfa-romero  16510.0
# 2  alfa-romero  16510.0
# 3         audi  13960.0
# 4         audi  17460.0

# %%
df['category'] = np.where(df['price'] >= 10000, 'high price', 'Low price')
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price    category
# 0              four         111               21  13505.0  high price
# ...

# %%
df[['company', 'price', 'category']].tail(5)
# Out:
#        company    price    category
# 56  volkswagen   7985.0   Low price
# 57  volkswagen   8005.0   Low price
# 58  volkswagen  10005.0  high price
# 59       volvo  12950.0  high price
# 60       volvo  13425.0  high price

# %%
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64
