# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Define matrix
A = np.array([[4, -2], 
              [1,  1]])

# Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

# Plot original eigenvectors
origin = np.array([0, 0])  # Origin for quiver plot

plt.quiver(*origin, eigenvectors[0, 0], eigenvectors[1, 0], color='r', angles='xy', scale_units='xy', scale=1, label='Eigenvector 1')
plt.quiver(*origin, eigenvectors[0, 1], eigenvectors[1, 1], color='b', angles='xy', scale_units='xy', scale=1, label='Eigenvector 2')

# Set plot limits
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid()
plt.legend()
plt.title("Eigenvectors of Matrix A")
plt.show()

# %%
#finding eigenvalues and eigenvectors
A = np.array([[4, -2], [1,1]])

# compute eignvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)
print(eigenvalues)
print(eigenvectors)
# Out:
# [3. 2.]
# [[0.89442719 0.70710678]
#  [0.4472136  0.70710678]]

# %%
import cv2

# %%
image = cv2.imread(r'Screenshot 2024-09-16 210643.png', cv2.IMREAD_GRAYSCALE)
img = np.array(image, dtype=np.float32)
img
# Out:
# array([[225., 225., 225., ..., 225., 225., 225.],
#        [225., 225., 225., ..., 225., 225., 225.],
#        [225., 225., 225., ..., 225., 225., 225.],
#        ...,
#        [226., 226., 227., ..., 226., 225., 225.],
#        [227., 224., 225., ..., 225., 225., 226.],
#        [226., 227., 226., ..., 227., 226., 225.]], dtype=float32)

# %%
image.shape
# Out:
# (1080, 1920)

# %%
u, s, vt = np.linalg.svd(image)
len(u)
# len(s)
# len(vt)
# Out:
# 1080

# %%
import numpy as np

# %%
compresed_image =np.dot(u[:,:100], np.dot(np.diag(s[:100]), vt[:100, :]))

# %%
plt.imshow(compresed_image, cmap='gray')

# %%
import sympy as sp

# %%
#finding derivative
x  = sp.symbols('x')
y = x**10
sp.diff(y, x)
# y
# Out:
# 10*x**9
