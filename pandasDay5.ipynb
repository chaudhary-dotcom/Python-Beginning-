# %%
import pandas as pd
import numpy as np

# %%
data = {
    'A': [1,2,3],
    'B': [4,5,6]
}

df = pd.DataFrame(data)
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.sum()
df.mean()
df.median()
df.min()
df.max()
df.count()
df.std()
df.var()
df.describe()
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %%
df.apply(lambda a: a*2)
df['B'].map(lambda b: b**2)
df
# Out:
#    A  B  Double  Double A
# 0  1  4       2         2
# 1  2  5       4         4
# 2  3  6       6         6

# %%
df['Double A'] = df.apply(lambda row: row['A'] * 2, axis=1)
df['Squared B'] = df['B'].apply(lambda a: a**2)
df
# Out:
#    A  B  Double A  Squared B
# 0  1  4         2         16
# 1  2  5         4         25
# 2  3  6         6         36

# %%
df['A_squared'] = df['A'].map(lambda a:a**2)
df
# Out:
#    A  B  Double A  Squared B  A_squared
# 0  1  4         2         16          1
# 1  2  5         4         25          4
# 2  3  6         6         36          9

# %%
df['A'].transform(lambda a: a**2)
# Out:
# 0    1
# 1    4
# 2    9
# Name: A, dtype: int64

# %%
df[df['B'] > 4]
df.loc[:1,['B']]
df.iloc[:2]
# Out:
#    A  B  Double A  Squared B  A_squared
# 0  1  4         2         16          1
# 1  2  5         4         25          4

# %%
df_z = pd.read_csv(r'C:\Users\user\OneDrive\Documents\DataScience\Python\Zomato-data-.csv')
df_z.info()
df_z.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df_z.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df_z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df_z['listed_in(type)'].value_counts().sort_values(ascending=False)
# df_z.groupby('listed_in(type)').size()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
# df_z['name'].value_counts().head()
# df_z.groupby('name').size()
# df_z.query('name == "CAFE NOVA" ')
# df_z.loc[df_z['name'] == 'CAFE NOVA']
# print(df_z.loc[df_z['listed_in(type)'] == 'Dining'])
df_z[df_z['name'].isin(['Spice Elephant', 'San Churro Cafe'])]

# df_z.groupby('listed_in(type)').size().sort_values(ascending=False)
# Out:
#                name online_order book_table   rate  votes  \
# 1    Spice Elephant          Yes         No  4.1/5    787
# 2   San Churro Cafe          Yes         No  3.8/5    918
# 14  San Churro Cafe          Yes         No  3.8/5    918
#
#     approx_cost(for two people) listed_in(type)
# 1                           800          Buffet
# 2                           800          Buffet
# 14                          800           Cafes

# %%
# df_z[df_z['name'].str.contains('ant', case=False)]
# df_z.info()
df_z[df_z['name'].apply(lambda a: a.lower() == 'spice elephant')]
# df_z.groupby('name').count()
# df_z.query('name == "Spice Elephant"')
# df_z.loc[df_z['name'] == 'Spice Elephant']
# Out:
#              name online_order book_table   rate  votes  \
# 1  Spice Elephant          Yes         No  4.1/5    787
#
#    approx_cost(for two people) listed_in(type)
# 1                          800          Buffet

# %%
df_z['rate'].value_counts().sort_values(ascending=False) 
# df_z.info()
# Out:
# rate
# 3.8/5     19
# 3.7/5     15
# 3.3/5     14
# 3.4/5     12
# 4.1/5     11
# 3.6/5     11
# 4.0/5     10
# 3.9/5     10
# 4.2/5      8
# 3.2/5      7
# 2.9/5      7
# 3.1/5      7
# 3.5/5      6
# 3.0/5      2
# 4.6/5      2
# 2.8/5      2
# 4.4/5      2
# 4.3/5      1
# 2.6/5      1
# 3.8 /5     1
# Name: count, dtype: int64

# %%
df_z.groupby('online_order').size().sort_values(ascending=False)
# Out:
# online_order
# No     90
# Yes    58
# dtype: int64

# %%
df_z.groupby('name')['name'].count().sort_values(ascending=False)
# df_z.query('name == "Onesta"')
# Out:
# name
# Onesta                   2
# San Churro Cafe          2
# CAFE NOVA                2
# Polar Bear               1
# Ovenstory Pizza          1
#                         ..
# Frozen Bottle            1
# Gawdaru Mane Beriyani    1
# Goa 0 Km                 1
# Grand Village            1
# XO Belgian Waffle        1
# Name: name, Length: 145, dtype: int64

# %%
df_z['name'].value_counts().get('CAFE NOVA', 0)
# Out:
# 2

# %%
df_z[df_z['votes']>1000].sort_values(by='votes', ascending=False)
# df_z.info()
# Out:
#                  name online_order book_table   rate  votes  \
# 38  Empire Restaurant          Yes         No  4.4/5   4884
# 86      Meghana Foods          Yes         No  4.4/5   4401
# 7              Onesta          Yes        Yes  4.6/5   2556
# 44             Onesta          Yes        Yes  4.6/5   2556
# 65        Kabab Magic          Yes         No  4.1/5   1720
# 37    Szechuan Dragon          Yes         No  4.2/5   1647
# 54       Roving Feast           No         No  4.0/5   1047
#
#     approx_cost(for two people) listed_in(type)
# 38                          750           other
# 86                          600          Dining
# 7                           600           Cafes
# 44                          600           other
# 65                          400          Dining
# 37                          600          Dining
# 54                          450          Dining

# %%
df_z.loc[:6, ['name', 'rate', 'book_table']]
# Out:
#                                               name   rate book_table
# 0                                            Jalsa  4.1/5        Yes
# 1                                   Spice Elephant  4.1/5         No
# 2                                  San Churro Cafe  3.8/5         No
# 3                            Addhuri Udupi Bhojana  3.7/5         No
# 4                                    Grand Village  3.8/5         No
# 5                                  Timepass Dinner  3.8/5         No
# 6  Rosewood International Hotel - Bar & Restaurant  3.6/5         No

# %%
df_z.iloc[0:2]
# Out:
#              name online_order book_table   rate  votes  \
# 0           Jalsa          Yes        Yes  4.1/5    775
# 1  Spice Elephant          Yes         No  4.1/5    787
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet

# %%
df_z.where(df_z['votes'] >100).count()
df_z.mask(df_z['votes']>100).count()
df_z.filter(items=['name', 'votes']).head()
# df_z.info()
# Out:
#                     name  votes
# 0                  Jalsa    775
# 1         Spice Elephant    787
# 2        San Churro Cafe    918
# 3  Addhuri Udupi Bhojana     88
# 4          Grand Village    166

# %%
df1=df_z[['name', 'votes']]
df1.head()
# Out:
#                     name  votes
# 0                  Jalsa    775
# 1         Spice Elephant    787
# 2        San Churro Cafe    918
# 3  Addhuri Udupi Bhojana     88
# 4          Grand Village    166

# %%
#merge
pd.merge(df_z, df1, on='name', how = 'inner')
# pd.merge(df_z, df1, on='votes', how = 'right').head(10)
# Out:
#                       name online_order book_table   rate  votes_x  \
# 0                    Jalsa          Yes        Yes  4.1/5      775
# 1           Spice Elephant          Yes         No  4.1/5      787
# 2          San Churro Cafe          Yes         No  3.8/5      918
# 3          San Churro Cafe          Yes         No  3.8/5      918
# 4    Addhuri Udupi Bhojana           No         No  3.7/5       88
# ..                     ...          ...        ...    ...      ...
# 149       Melting Melodies           No         No  3.3/5        0
# 150        New Indraprasta           No         No  3.3/5        0
# 151           Anna Kuteera          Yes         No  4.0/5      771
# 152                 Darbar           No         No  3.0/5       98
# 153          Vijayalakshmi          Yes         No  3.9/5       47
#
#      approx_cost(for two people) listed_in(type)  votes_y
# 0                            800          Buffet      775
# 1                            800          Buffet      787
# 2                            800          Buffet      918
# 3                            800          Buffet      918
# 4                            300          Buffet       88
# ..                           ...             ...      ...
# 149                          100          Dining        0
# 150                          150          Dining        0
# 151                          450          Dining      771
# 152                          800          Dining       98
# 153                          200          Dining       47
#
# [154 rows x 8 columns]

# %%
df3= pd.concat([df_z, df1], axis=1)
# df1.info()
# df_z.info()
df3.tail(5)
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)              name  votes
# 143                          100          Dining  Melting Melodies      0
# 144                          150          Dining   New Indraprasta      0
# 145                          450          Dining      Anna Kuteera    771
# 146                          800          Dining            Darbar     98
# 147                          200          Dining     Vijayalakshmi     47

# %%
# # df_z.join(df1, how='left')
# df_z.append(df1, ignore_in)

# %%
df3.isna().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# name                           0
# votes                          0
# dtype: int64

# %%
df3.notna().sum()
# Out:
# name                           148
# online_order                   148
# book_table                     148
# rate                           148
# votes                          148
# approx_cost(for two people)    148
# listed_in(type)                148
# name                           148
# votes                          148
# dtype: int64

# %%
df3.dropna().count()
# Out:
# name                           148
# online_order                   148
# book_table                     148
# rate                           148
# votes                          148
# approx_cost(for two people)    148
# listed_in(type)                148
# name                           148
# votes                          148
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df_z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
votelist = df_z['approx_cost(for two people)'].tolist()
cost_list = df_z['votes'].tolist()
plt.plot(votelist, cost_list, label = 'month wise')
plt.xlabel('votes')
plt.ylabel('approx_cost(for two people)')
plt.show()
